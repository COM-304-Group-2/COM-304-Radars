# %%
import mmwavecapture.radar
import mmwavecapture.dca1000

# Initialize the DCA1000EVM
dca = mmwavecapture.dca1000.DCA1000()
dca.config.dca_ip = "192.168.33.180"
dca.config.dca_config_port = 4096

# Initialize the radar
cfg_file = "configs/profile_1.cfg"
radar = mmwavecapture.radar.Radar(
    config_port="/dev/tty.usbmodemR20910491",
    config_baudrate=115200,
    data_port="/dev/tty.usbmodemR20910494",
    data_baudrate=921600,
    config_filename=cfg_file,
    initialize_connection_and_radar=True,
    capture_frames=0,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/rt2_env/lib/python3.13/site-packages/serial/serialposix.py:322, in Serial.open(self)
#     321 try:
# --> 322     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323 except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/tty.usbmodemR20910491'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# Cell In[1], line 11
#       9 # Initialize the radar
#      10 cfg_file = "configs/profile_1.cfg"
# ---> 11 radar = mmwavecapture.radar.Radar(
#      12     config_port="/dev/tty.usbmodemR20910491",
#      13     config_baudrate=115200,
#      14     data_port="/dev/tty.usbmodemR20910494",
#      15     data_baudrate=921600,
#      16     config_filename=cfg_file,
#      17     initialize_connection_and_radar=True,
#      18     capture_frames=0,
#      19 )
#
# File ~/Documents/EPFL/BA6/Communications project/Group_2/COM-304-Radars/project/mmwavecapture/radar.py:178, in Radar.__init__(self, config_port, config_baudrate, data_port, data_baudrate, config_filename, timeout, initialize_connection_and_radar, capture_frames)
#     175 self._data_serial = serial.Serial()
#     177 if initialize_connection_and_radar:
# --> 178     self.initialize()
#
# File ~/Documents/EPFL/BA6/Communications project/Group_2/COM-304-Radars/project/mmwavecapture/radar.py:282, in Radar.initialize(self)
#     280 def initialize(self) -> None:
#     281     """Connect to radar and flush the radar config serial buffer"""
# --> 282     self.connect_serials()
#     283     self._flush_radar_config_serial_buffer()
#     284     self._initialized = True
#
# File ~/Documents/EPFL/BA6/Communications project/Group_2/COM-304-Radars/project/mmwavecapture/radar.py:291, in Radar.connect_serials(self)
#     289 self._config_serial.baudrate = self._config_baudrate
#     290 self._config_serial.timeout = self._timeout
# --> 291 self._config_serial.open()
#     293 self._data_serial.port = self._data_port
#     294 self._data_serial.baudrate = self._data_baudrate
#
# File ~/anaconda3/envs/rt2_env/lib/python3.13/site-packages/serial/serialposix.py:325, in Serial.open(self)
#     323 except OSError as msg:
#     324     self.fd = None
# --> 325     raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     326 #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     328 self.pipe_abort_read_r, self.pipe_abort_read_w = None, None
#
# SerialException: [Errno 2] could not open port /dev/tty.usbmodemR20910491: [Errno 2] No such file or directory: '/dev/tty.usbmodemR20910491'

# %%
# Check DCA1000EVM connection
if not dca.system_connection():
    raise RuntimeError(f"DCA1000EVM connection error at {4096}")

# Initialize DCA1000EVM
dca.reset_radar()
dca.reset_fpga()
dca.config_fpga()
dca.config_packet_delay()
# Out:
# True

# %%
# Initialize radar
radar.initialize()
radar.config()
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Initialize radar
# ----> 2 radar.initialize()
#       3 radar.config()
#
# File ~/Documents/EPFL/BA6/Communications project/Group_2/COM-304-Radars/project/mmwavecapture/radar.py:282, in Radar.initialize(self)
#     280 def initialize(self) -> None:
#     281     """Connect to radar and flush the radar config serial buffer"""
# --> 282     self.connect_serials()
#     283     self._flush_radar_config_serial_buffer()
#     284     self._initialized = True
#
# File ~/Documents/EPFL/BA6/Communications project/Group_2/COM-304-Radars/project/mmwavecapture/radar.py:291, in Radar.connect_serials(self)
#     289 self._config_serial.baudrate = self._config_baudrate
#     290 self._config_serial.timeout = self._timeout
# --> 291 self._config_serial.open()
#     293 self._data_serial.port = self._data_port
#     294 self._data_serial.baudrate = self._data_baudrate
#
# File ~/anaconda3/envs/rt2_env/lib/python3.13/site-packages/serial/serialposix.py:318, in Serial.open(self)
#     316     raise SerialException("Port must be configured before it can be used.")
#     317 if self.is_open:
# --> 318     raise SerialException("Port is already open.")
#     319 self.fd = None
#     320 # open
#
# SerialException: Port is already open.

# %%
radar.config()
radar.get_radar_status()
# Out:
# (<RadarStatus.INIT: 0>, 921600)

# %%
# Start DCA1000EVM
dca.start_record()
radar.start_sensor()

# %%
socket_data = dca.get_socket_data("data")
socket_config = dca.get_socket_data("config")

# %%
socket_data.close()
socket_config.close()

# %%
from streaming import (realtime_streaming_2)

realtime_streaming_2.main(
    exp_num=0,
    lua_file=cfg_file)
# Out:
# Known pipe types:
#   CocoaGraphicsPipe
# (all display modules loaded.)
# ✅ Shutdown complete.
